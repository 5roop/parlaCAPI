# %% [markdown]
# # Figuring out filtering

# %%
filter = {
    "filter": {
        "operator": "NOT",
        "filters": [
            {"column": "speaker_gender", "operator": "IN", "value": ["M", "F"]},
        ],
    },
    "limit": 5,
    "offset": 0,
}

import requests

url = "https://parlacap.ipipan.waw.pl/"
response = requests.post(
    url + "filter",
    json=filter,
)
if not response.status_code == 200:
    raise Exception(
        f"Got weird response code: {response.status_code}, response text: {response.text}"
    )

payload = response.json()
payload
# Out:
# [{'id': 358439,
#   'parlacap_id': 'ParlaCAP-BE_2014-09-03_00003',
#   'parlamint_text_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x',
#   'parlamint_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x.u3',
#   'date': '2014-09-03',
#   'parliament': 'BE',
#   'vdem_country_id': 148,
#   'lang': 'Multilingual',
#   'speaker_role': 'Guest',
#   'speaker_mp': 'notMP',
#   'speaker_minister': 'notMinister',
#   'speaker_party': None,
#   'speaker_party_name': None,
#   'party_status': None,
#   'party_orientation': None,
#   'partyfacts_id': None,
#   'speaker_id': 'BensJan',
#   'speaker_name': 'Bens, Jan',
#   'speaker_gender': 'U',
#   'speaker_birth': None,
#   'word_count': 1508,
#   'cap_category': 'Energy',
#   'cap_prob': 0.989,
#   'sent_logit': 2.157,
#   'sent3_category': 'Neutral',
#   'sent6_category': 'Neutral Negative',
#   'text': 'Mijnheer de voorzitter, mevrouw de voorzitter, geachte leden, bedankt voor de uitnodiging om wat toelichting te komen geven over de toestand van de kerncentrales in België. Vooraleer ik aan die toelichting begin, had ik graag even het FANC gesitueerd, het Federaal Agentschap voor Nucleaire Controle. Onze hoofdmissie is de bescherming van de bevolking, de werknemers en het leefmilieu tegen de schadelijke effecten van radioactiviteit. Zaken zoals de energiebevoorrading komen, zoals de voorzitter in de inleiding al heeft gezegd, mijn collega’s van Elia toe, die daarop straks zullen ingaan. Om de gedachten te vestigen, heb ik in mijn slides ook een stuk opgenomen uit de wet omtrent de kernuitstap. Die wet, goedgekeurd in 2003 en in december 2013 nog gewijzigd, bepaalt voor de zeven reactoren een datum waarop de elektriciteitsproductie moet stoppen. Ik bespreek nu de verschillende sites, waarvan als eerste Tihange 1. En ce qui concerne le site de Tihange 1, dont la fermeture est prévue le 1er octobre 2025, cette centrale est en état normal de fonctionnement. Cependant, pour l’instant, elle est à l’arrêt pour le rechargement planifié. Tihange 1 a un cycle de dix-huit mois pour ses arrêts de rechargement. Les mois de septembre et octobre étaient prévus pour cela. Compte tenu de la situation, Electrabel a décidé de raccourcir la durée de cet arrêt, qui était normalement planifié pour sept ou huit semaines, afin que la centrale soit de nouveau disponible fin octobre - début novembre. La période de rechargement sert à recharger le cœur, remettre du combustible frais, opérer des travaux de maintenance et de contrôle normaux, ainsi que des travaux d’amélioration. Ces derniers sont spécifiques à l’arrêt de tranche de cette année-ci: ils sont dus à la réévaluation périodique décennale de la sûreté. Des investissements d’amélioration de la conception ont été décidés – design upgrades, comme on dit dans le jargon. De plus, certains travaux doivent être faits dans le c
is planned for 2016 for the reloading of the heart and normal maintenance work. With regard to Tihange 2, the planned stop date is 1 February 2023. It is one of two reactors with hydrogen defects in the reactor tank. On March 26 of this year, we realized that, following the tests that the Agency had requested on the samples – to irradiate them – these irradiation tests had unexpected results. Since we didn't understand what it was due to, we decided to shut down the Tihange 2 and Doel 3 reactors, which are in the same condition. In the meantime, Electrabel has carried out additional studies, irradiation tests which are still ongoing at the Mol Research Centre in the BR-2 reactor (Belgian Reactor nr 2). Even yesterday afternoon, I attended a meeting with Electrabel, who informed us about the state of work and future trials. The first very rough results confirm the results we had in March. There is an irradiation effect on steel with hydrogen defects and the mechanism that causes this unexpected effect is still unknown. Before restarting, the Agency's terms and conditions remain the same. We must first be able to explain the phenomena. With this new knowledge, it is a matter of rewriting a dossier to justify the safety of the reactor. The tank is a very special equipment of the reactor. Everything can break in a nuclear power plant. Safety systems intervene to remedy this. But the reactor tank can't break. So we are much stricter. Electrabel promises to get the results in autumn. In my opinion, this will be more for the end of autumn than the beginning. When Electrabel has submitted its files, the Federal Agency will also be able to carry out its ow ...
#  {'id': 358453,
#   'parlacap_id': 'ParlaCAP-BE_2014-09-03_00017',
#   'parlamint_text_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x',
#   'parlamint_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x.u17',
#   'date': '2014-09-03',
#   'parliament': 'BE',
#   'vdem_country_id': 148,
#   'lang': 'Multilingual',
#   'speaker_role': 'Guest',
#   'speaker_mp': 'notMP',
#   'speaker_minister': 'notMinister',
#   'speaker_party': None,
#   'speaker_party_name': None,
#   'party_status': None,
#   'party_orientation': None,
#   'partyfacts_id': None,
#   'speaker_id': 'BensJan',
#   'speaker_name': 'Bens, Jan',
#   'speaker_gender': 'U',
#   'speaker_birth': None,
#   'word_count': 2637,
#   'cap_category': 'Energy',
#   'cap_prob': 0.987,
#   'sent_logit': 2.044,
#   'sent3_category': 'Neutral',
#   'sent6_category': 'Neutral Negative',
#   'text': "Mijnheer de voorzitter, ik ben blij met de grote interesse. Ik moet toch iets verduidelijken. Ik ben daarnet misschien niet duidelijk genoeg geweest over wat Electrabel mij gisteren heeft verteld. Verschillende mensen hebben blijkbaar begrepen dat het volledig pakket van resultaten is gegeven, maar dat is niet zo. Electrabel heeft ons gezegd wat het tijdens de zomer heeft gedaan en hoever het staat. Zo’n test is tamelijk ingewikkeld: men moet een monstertje maken, het uit een blok halen en bestralen in een reactor. Dan wordt het monster hoogradioactief, waardoor men het niet meer kan manipuleren, maar men met telemanipulatoren in afgesloten ruimtes moet werken. Dat zijn zaken die heel veel tijd vragen. Vervolgens moeten trek- en breuktesten worden uitgevoerd op de monstertjes. Die testen zijn echter allemaal nog bezig. Het ganse pakket van resultaten is dus nog niet beschikbaar. Men heeft de testen zodanig georganiseerd dat er enkele zo snel mogelijk konden worden uitgevoerd. Uit die eerste, voorlopige resultaten gaat men na welke andere tests men kan doen. Het enige wat al duidelijk is, is dat een aantal pistes die in april bestonden toen de fenomenen werden opgemerkt, kunnen worden uitgesloten. Op dat moment wist men immers echt niet wat er was gebeurd en wat de mogelijkheden waren. Er bestonden toen heel wat verschillende pistes: ligt het probleem aan de manier van beproeven, ligt het aan de BR2-reactor, ligt het aan de manier van testen? Men heeft echter nog niet genoeg informatie om te stellen welk fenomeen zich voordoet. Er is dus zeker geen hoerastemming omdat alle tests binnen zijn. Tot vorige week hadden wij zelfs geen zicht op een stand van zaken. Nu hebben wij dat wel en weten wij in welke richting de andere activiteiten gaan. Er werd gezegd de testresultaten direct op te vragen. Ik denk niet dat er al een degelijk document bestaat dat men ons kan overhandigen. Er werd ons een tipje van de sluier opgelicht, maar er is nog heel veel werk bezig om de tests uit te voeren, ze te interpreteren en met elkaar te verbinden. Er waren een paar vragen over internationale normen inzake beveiliging. Het Internationaal Atoomenergieagentschap in Wenen heeft richtlijnen over de beveiliging van kerncentrales. Wij implementeren die richtlijnen uiteraard. De turbine ligt niet in de nucleaire zone, maar valt toch onder de bevoegdheid van het FANC. Op dat vlak heeft het Belgisch Parlement proactief opgetreden. In 2011 werden immers enkele wetten en koninklijke besluiten uitgevaardigd om de beveiliging beter te organiseren, waardoor het FANC enkele extra bevoegdheden kreeg op dat vlak. Het past ook in de bescherming van de kritische infrastructuren. Andere kritische infrastructuur voor ons land die absoluut niets te maken heeft met nucleaire energie of energiebevoorrading, valt onder een andere bevoegdheid. Men heeft specifiek de electronucleaire groepen opgenomen en gesteld dat het FANC ook ten aanzien van hen die bevoegdheid heeft. Het is, net zoals voor de veiligheid, altijd de exploitant die in de eerste lijn verantwoordelijk is voor de beveiliging. Het is een internationaal erkend principe dat de exploitant de veiligheid van zijn installaties moet aantonen en dat de overheid erop moet toezien. Het is niet omgekeerd. Het FANC neemt die verantwoordelijkheid niet over van de exploitant. De exploitant blijft de eerste verantwoordelijke, zowel voor de veiligheid als voor de beveiliging van zijn installaties. Er is een vraag gesteld naar peer review. Wij hebben regelmatig contact met onze internationale collega’s. Er bestaat een groep van de verschillende Europese regulatoren, die meerdere keren per jaar over de beveiliging samenkomt en informatie uitwisselt. Dan kom ik tot de vragen over de Long-Term Operation van Tihange 1 en Doel 2. Voor Tihange 1 was het engagement dat een aantal werken zouden gebeuren voor de veertigste verjaardag, dus vóór 1 oktober van volgend jaar. Dat die werken verschoven zijn van september en oktober ...
#   'text_en': "Mr President, I welcome the great interest. There's something I need to clarify. I may not have been clear enough about what Electrabel told me yesterday. Several people seem to have understood that the full package of results has been given, but that is not the case. Electrabel has told us what it has done during the summer and how far it is. Such a test is rather complicated: one has to make a sample, extract it from a block and irradiate it in a reactor. Then the monster becomes highly radioactive, which means that one can no longer manipulate it, but has to work with telemanipulators in enclosed spaces. Those are things that take a lot of time. Tensile and fracture tests shall then be carried out on the samples. However, these tests are all still ongoing. The whole package of results is therefore not yet available. The tests were organized in such a way that some could be carried out as quickly as possible. From these first, preliminary results one examines what other tests can be done. The only thing that is already clear is that a number of slopes that existed in April when the phenomena were noted can be excluded. At that time, they really did not know what had happened and what the possibilities were. There were a lot of different slopes at the time: is the problem due to the way of testing, is it the BR2 reactor, is it the way of testing? However, there is not enough information yet to determine which phenomenon is occurring. So there is certainly no hurray mood because all the tests are in. Until last week, we did not even see a state of affairs. Now we have that and we know where the other activities are heading. They were told to get the test results straight away. I do not think there is already a solid document that can be handed over to us. A tip of the veil was lifted, but a lot of work is still in progress to carry out the tests, to interpret them and to connect them. There were a few questions about international security standards. The International Atomic Energy Agency in Vienna has directives on the security of nuclear power plants. We are, of course, implementing these guidelines. The turbine is not located in the nuclear zone, but still falls within the competence of the FANC. In this respect, the Belgian Parliament has acted proactively. In 2011, some laws and royal decrees were passed to better organise security, giving the FANC some additional powers in this area. It also fits in with the protection of critical infrastructures. Other critical infrastructure for our country which has absolutely nothing to do with nuclear energy or energy supplies is under another jurisdiction. It has specifically included the electronuclear groups and it has been said that the FANC also has the power to do so. As for safety, it is always the operator responsible for security in the first line. It is an internationally recognised principle that the operator must demonstrate the safety of his installations and that the public authorities must monitor them. It's not the other way around. The FANC shall not assume that responsibility from the operator. An operator shall remain the first responsible for both the safety and the security of its installations. A question has been asked about peer review. We have regular contact with our international colleagues. There is a group of the different European regulators, which meets several times a year about security and exchanges information. Then I come to the questions about the Long-Term Operation of Tihange 1 and Target 2. For Tihange 1, the commitment was that a number of works would take place before the 40th anniversary, i.e. before 1 October of next year. The fact that these works have been postponed from September and October of this year to the summer of next year is fully in line with that commitment. So we have no problem with that. What about Objective 1 and Objective 2? The file on what needs to be done to improve the design was parallel for Tihange 1  ...
#  {'id': 358458,
#   'parlacap_id': 'ParlaCAP-BE_2014-09-03_00022',
#   'parlamint_text_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x',
#   'parlamint_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x.u22',
#   'date': '2014-09-03',
#   'parliament': 'BE',
#   'vdem_country_id': 148,
#   'lang': 'Multilingual',
#   'speaker_role': 'Guest',
#   'speaker_mp': 'notMP',
#   'speaker_minister': 'notMinister',
#   'speaker_party': None,
#   'speaker_party_name': None,
#   'party_status': None,
#   'party_orientation': None,
#   'partyfacts_id': None,
#   'speaker_id': 'BensJan',
#   'speaker_name': 'Bens, Jan',
#   'speaker_gender': 'U',
#   'speaker_birth': None,
#   'word_count': 317,
#   'cap_category': 'Energy',
#   'cap_prob': 0.988,
#   'sent_logit': 1.963,
#   'sent3_category': 'Neutral',
#   'sent6_category': 'Neutral Negative',
#   'text': "Monsieur le président, en ce qui concerne le chemin à suivre pour les résultats des microfissures, nous voulons deux réponses. Nous voulons savoir quel phénomène physique a causé ce non-hardening embrittlement, comme on dit dans le jargon, donc la différence entre ce que nous avons vu et ce que la théorie avait prédit. On doit nous donner une explication physique claire sur ce point. Si nous ne savons pas pourquoi cela se passe de cette façon, nous ne sommes pas d'accord pour redémarrer. C'est très clair. L'autre résultat clair que nous voulons est un dossier d'évaluation de sûreté, une étude qui détermine – avec les caractéristiques des cuves qui sont bien mieux spécifiées – que les cuves tiendront en cas d'accident. Ce sont les deux questions fondamentales auxquelles doit répondre Electrabel. Mijnheer Calvo, het KB inzake fysieke beveiliging wordt geïmplementeerd. Er zijn sinds de uitvaardiging van dat KB al heel wat verbeteringen aangebracht op de verschillende sites, niet alleen bij de kerncentrales maar ook in Mol-Dessel en Fleurus. Er is ter zake sprake van een timing, want het gaat hierbij over aanzienlijke investeringen. Dit alles wordt op periodieke basis opgevolgd. Een aantal investeringen lopen momenteel nog. Het is heel duidelijk dat de timing van Electrabel niet aangenaam is voor ons. De vingers van onze experten jeuken om erin te vliegen, om over de gegevens te beschikken en om hun analyses uit te voeren. Het is ook die frustratie die naar boven is gekomen in het interview van afgelopen weekend. Wij hebben evenwel geen wettelijke basis om die resultaten op te eisen. De vergunning voor die centrales is destijds uitgereikt en het is eigenlijk aan de exploitant om te beslissen over de operationalisering. Als zij operationeel willen worden, moeten wij daarvoor de goedkeuring geven. Als de exploitant er geen probleem mee heeft om zijn installaties stil te laten liggen, dan kunnen wij als veiligheidsautoriteit daarover moeilijk opmerkingen maken.",
#   'text_en': "Mr President, as regards the way forward for the results of micro-cracks, we want two answers. We want to know what physical phenomenon caused this non-hardening embryontly, as we say in jargon, so the difference between what we saw and what the theory predicted. We need a clear physical explanation on this point. If we do not know why this is happening in this way, we do not agree to restart. That's very clear. The other clear result we want is a safety assessment file, a study that determines – with the characteristics of the tanks that are much better specified – that the tanks will hold in the event of an accident. These are the two fundamental questions to be answered by Electrabel. Mr Calvo, the KB on physical security is being implemented. Many improvements have been made on the various sites, not only at the nuclear power stations but also in Mol-Dessel and Fleurus, since the KB was issued. We are talking about timing here, because we are talking about significant investments. All this will be monitored on a regular basis. A number of investments are still ongoing. It is quite clear that the timing of Electrabel is not pleasant for us. The fingers of our experts itch to fly in, to have the data and to carry out their analyses. It's also that frustration that came up in last weekend's interview. However, we do not have a legal basis for demanding these results. The licence for these plants was issued at the time and it is actually up to the operator to decide on the operationalisation. If they want to become operational, we have to approve it. If the operator does not have a problem with keeping his installations stationary, then it is difficult for us as a safety authority to comment on this."},
#  {'id': 358460,
#   'parlacap_id': 'ParlaCAP-BE_2014-09-03_00024',
#   'parlamint_text_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x',
#   'parlamint_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x.u24',
#   'date': '2014-09-03',
#   'parliament': 'BE',
#   'vdem_country_id': 148,
#   'lang': 'Dutch',
#   'speaker_role': 'Guest',
#   'speaker_mp': 'notMP',
#   'speaker_minister': 'notMinister',
#   'speaker_party': None,
#   'speaker_party_name': None,
#   'party_status': None,
#   'party_orientation': None,
#   'partyfacts_id': None,
#   'speaker_id': 'BensJan',
#   'speaker_name': 'Bens, Jan',
#   'speaker_gender': 'U',
#   'speaker_birth': None,
#   'word_count': 42,
#   'cap_category': 'Energy',
#   'cap_prob': 0.976,
#   'sent_logit': 1.538,
#   'sent3_category': 'Neutral',
#   'sent6_category': 'Neutral Negative',
#   'text': 'Onze nucleaire inspecteurs hebben een verordening geschreven waaruit voortvloeit dat zij niet mogen opstarten zonder onze goedkeuring. Dat is niet helemaal hetzelfde als de vergunning formeel intrekken, want dat is een vrij lange procedure die uiteindelijk via een koninklijk besluit moet verlopen.',
#   'text_en': 'Our nuclear inspectors have written a regulation to prevent them from starting without our approval. That is not quite the same as formally withdrawing the licence, because that is a rather lengthy procedure which must ultimately be carried out by a royal decision.'},
#  {'id': 358462,
#   'parlacap_id': 'ParlaCAP-BE_2014-09-03_00026',
#   'parlamint_text_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x',
#   'parlamint_id': 'ParlaMint-BE_2014-09-03-54-commissie-ic004x.u26',
#   'date': '2014-09-03',
#   'parliament': 'BE',
#   'vdem_country_id': 148,
#   'lang': 'Dutch',
#   'speaker_role': 'Guest',
#   'speaker_mp': 'notMP',
#   'speaker_minister': 'notMinister',
#   'speaker_party': None,
#   'speaker_party_name': None,
#   'party_status': None,
#   'party_orientation': None,
#   'partyfacts_id': None,
#   'speaker_id': 'BensJan',
#   'speaker_name': 'Bens, Jan',
#   'speaker_gender': 'U',
#   'speaker_birth': None,
#   'word_count': 10,
#   'cap_category': 'Health',
#   'cap_prob': 0.99,
#   'sent_logit': 3.185,
#   'sent3_category': 'Neutral',
#   'sent6_category': 'Neutral Positive',
#   'text': 'Hoe helpt dit de volksgezondheid? Hoe beschermt dit de mensen?',
#   'text_en': 'How does this help public health? How does this protect people?'}]

# %% [markdown]
# # In search of null filtering
#
# This does not seem to work. I keep getting Nginx Gateway Timeout errors

# %%
filter = {
    "filter": {"column": "cap_category", "value": None, "operator": "="},
    "limit": 1,
    "offset": 10,
}

response = requests.post(
    url + "filter",
    json=filter,
)
if not response.status_code == 200:
    raise Exception(
        f"Got weird response code: {response.status_code}, response text: {response.text}"
    )

payload = response.json()
payload
# Out:
# [{'id': 6675284,
#   'parlacap_id': 'ParlaCAP-SI_2012-04-21_00011',
#   'parlamint_text_id': 'ParlaMint-SI_2012-04-21-SDZ6-Izredna-42',
#   'parlamint_id': 'ParlaMint-SI_2012-04-21-SDZ5-Izredna-42.u11',
#   'date': '2012-04-21',
#   'parliament': 'SI',
#   'vdem_country_id': 202,
#   'lang': 'Slovenian',
#   'speaker_role': 'Chairperson',
#   'speaker_mp': 'notMP',
#   'speaker_minister': 'notMinister',
#   'speaker_party': None,
#   'speaker_party_name': None,
#   'party_status': None,
#   'party_orientation': None,
#   'partyfacts_id': None,
#   'speaker_id': 'GantarPavel',
#   'speaker_name': 'Gantar, Pavel',
#   'speaker_gender': 'M',
#   'speaker_birth': 1949,
#   'word_count': 13,
#   'cap_category': None,
#   'cap_prob': None,
#   'sent_logit': 3.199,
#   'sent3_category': 'Neutral',
#   'sent6_category': 'Neutral Positive',
#   'text': 'Hvala lepa. Stališče Poslanske skupine demokratične stranke upokojencev Slovenije bo predstavil Franc Jurša.',
#   'text_en': 'Thank you very much. The position of the Group of the Democratic Party of Pensioners of Slovenia will be presented by Franc Jurša.'}]

# %% [markdown]
# # Checking hunches with sampling
#
# Let's see on a sample of 60*500 instances if we find any non-null parlmint_text_id, parlmint_id, cap_prob, and cap_category values:

# %%
N = 1
examined = 0
textidcount, idcount, cap_category, cap_prob, sent_logit = 0, 0, 0, 0, 0
for i in range(N):
    url = "https://parlacap.ipipan.waw.pl/"
    take_n = 500
    import json
    import requests

    response = requests.get(url + f"sample?size={take_n}")
    if not response.status_code == 200:
        raise Exception(
            f"Got weird response code: {response.status_code}, response text: {response.text}"
        )

    payload = response.json()
    textidcount += len([i for i in payload if i["parlamint_text_id"] is not None])
    idcount += len([i for i in payload if i["parlamint_id"] is not None])
    cap_category += len([i for i in payload if i["cap_category"] is not None])
    cap_prob += len([i for i in payload if i["cap_prob"] is not None])
    sent_logit += len([i for i in payload if i["sent_logit"] is not None])
    examined += take_n
    print(
        f"Examined: {examined} instances, found nonnulls: {textidcount=}, {idcount=}, {cap_prob=}, {cap_category=}, {sent_logit=}",
        end="\r",
    )
# Out:
# Examined: 500 instances, found nonnulls: textidcount=500, idcount=500, cap_prob=500, cap_category=500, sent_logit=500

# %% [markdown]
# # Testing issues found by MM
#
# Let's test if downloading in CSV format works:

# %%
url = "https://parlacap.ipipan.waw.pl/"


filter = {
    "filter": {"column": "parliament", "value": "SI", "operator": "="},
    "limit": 100,
    "offset": 10,
}

response = requests.post(
    url + "download?format=csv",
    json=filter,
)
if not response.status_code == 200:
    raise Exception(
        f"Got weird response code: {response.status_code}, response text: {response.text}"
    )
with open("downloaded_data.csv", "wb") as f:
    f.write(response.content)

# %%
import pandas as pd

df = pd.read_csv(
    "downloaded_data.csv",
)
print(df.dtypes)
df.head(2)
# Out:
# id                      int64
# parlacap_id            object
# parlamint_text_id      object
# parlamint_id           object
# date                   object
# parliament             object
# vdem_country_id         int64
# lang                   object
# speaker_role           object
# speaker_mp             object
# speaker_minister       object
# speaker_party          object
# speaker_party_name     object
# party_status           object
# party_orientation      object
# partyfacts_id         float64
# speaker_id             object
# speaker_name           object
# speaker_gender         object
# speaker_birth         float64
# word_count              int64
# cap_category           object
# cap_prob              float64
# sent_logit            float64
# sent3_category         object
# sent6_category         object
# text                   object
# text_en                object
# dtype: object
#         id                   parlacap_id  \
# 0  6502516  ParlaCAP-SI_2000-10-27_00011
# 1  6502517  ParlaCAP-SI_2000-10-27_00012
#
#                        parlamint_text_id  \
# 0  ParlaMint-SI_2000-10-27-SDZ3-Redna-01
# 1  ParlaMint-SI_2000-10-27-SDZ3-Redna-01
#
#                                 parlamint_id        date parliament  \
# 0  ParlaMint-SI_2000-10-27-SDZ3-Redna-01.u11  2000-10-27         SI
# 1  ParlaMint-SI_2000-10-27-SDZ3-Redna-01.u12  2000-10-27         SI
#
#    vdem_country_id       lang speaker_role speaker_mp  ... speaker_gender  \
# 0              202  Slovenian      Regular         MP  ...              M
# 1              202  Slovenian  Chairperson         MP  ...              M
#
#   speaker_birth word_count           cap_category cap_prob  sent_logit  \
# 0        1948.0         64  Government Operations    0.947       1.603
# 1        1924.0         40                  Other    0.998       2.934
#
#   sent3_category    sent6_category  \
# 0        Neutral  Neutral Negative
# 1        Neutral  Neutral Positive
#
#                                                 text  \
# 0  Spoštovane poslanke in poslanci. Govorim v ime...
# 1  Hvala lepa. Želi še kakšna poslanska skupina b...
#
#                                              text_en
# 0  Dear Members and Members. I speak on behalf of...
# 1  Thank you very much. Does any other parliament...
#
# [2 rows x 28 columns]

# %%
import polars as pl

df = pl.read_csv("downloaded_data.csv", skip_rows=7)
df.head(2)

# %%
df.dtypes

df["speaker_name"].describe()

# %%
for format in ["csv", "jsonl", "tsv", "parquet"]:
    url = "https://parlacap.ipipan.waw.pl/"
    filter = {
        "filter": {"column": "parliament", "value": "SI", "operator": "="},
        "limit": 10,
        "offset": 10,
    }

    response = requests.post(
        url + f"download?format={format}",
        json=filter,
    )
    if not response.status_code == 200:
        raise Exception(
            f"Got weird response code: {response.status_code}, response text: {response.text}"
        )
    with open(f"downloaded_data.{format}", "wb") as f:
        f.write(response.content)

# %%
import pandas as pd

pd.read_parquet("downloaded_data.parquet").head(2)
# Out:
#         id parlmint_text_id parlmint_id        date parliament  \
# 0  6502516             None        None  2000-10-27         SI
# 1  6502517             None        None  2000-10-27         SI
#
#    vdem_country_id       lang speaker_role speaker_mp speaker_minister  ...  \
# 0              202  Slovenian      Regular       None         Minister  ...
# 1              202  Slovenian  Chairperson       None      notMinister  ...
#
#   speaker_gender speaker_birth word_count cap_category cap_prob sent_logit  \
# 0              M        1948.0         64         None     None      1.603
# 1              M        1924.0         40         None     None      2.934
#
#   sent3_category    sent6_category  \
# 0        Neutral  Neutral Negative
# 1        Neutral  Neutral Positive
#
#                                                 text  \
# 0  Spoštovane poslanke in poslanci. Govorim v ime...
# 1  Hvala lepa. Želi še kakšna poslanska skupina b...
#
#                                              text_en
# 0  Dear Members and Members. I speak on behalf of...
# 1  Thank you very much. Does any other parliament...
#
# [2 rows x 27 columns]

# %%
url = "https://parlacap.ipipan.waw.pl/"


filter = {
    "filter": {"column": "parliament", "value": "SI", "operator": "="},
    "limit": 100,
    "offset": 10_000_000,
}

response = requests.post(
    url + "filter",
    json=filter,
)
if not response.status_code == 200:
    raise Exception(
        f"Got weird response code: {response.status_code}, response text: {response.text}"
    )

response.json()

# %% [markdown]
# # What do LIKE and IN do?

# %%
filter = {
    "filter": {
        "operator": "AND",
        "filters": [
            {"column": "speaker_party", "operator": "IN", "value": ["NSi", "SDS"]},
            {"column": "parliament", "operator": "IN", "value": ["SI"]},
        ],
    },
    "columns": [
        "id",
        "speaker_role",
        "speaker_mp",
        "speaker_party",
        "speaker_party_name",
        "party_status",
        "speaker_name",
        "speaker_birth",
        "text",
    ],
    "order_by": ["id"],
    "limit": 100,
    "offset": 0,
}


response = requests.post(
    url + "filter",
    json=filter,
)
if not response.status_code == 200:
    raise Exception(
        f"Got weird response code: {response.status_code}, {response.content}"
    )

payload = response.json()
payload
set([i["speaker_party"] for i in payload])

# %%
import polars as pl

df = pl.read_excel("downloaded_data_metadata.xlsx")
df
# Out:
# shape: (10, 28)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │